# %% [markdown]
# <a href="https://colab.research.google.com/github/xang1212/datamining/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ເປັນການ import pandas library ແລະ numpy library  ເຂົ້າມາໃຊ້

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ເປັນການກວດສອບ version ຂອງ pandas library ແລະ numpy library

# %%
print(f'pandas version: {pd.__version__}')
print(f'numpy  version: {np.__version__}')
# Out:
# pandas version: 1.3.5
# numpy  version: 1.21.6

# %% [markdown]
# ອ່ານຂໍ້ມູນຈາກ link file csv ແລ້ວນຳຂໍ້ມູນອອກມາສະແດ
# ງດ້ວຍການ random 20 ຕົວຢ່າງ

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
df=df.sample(20, random_state=123)
df
# Out:
#                               name         genus   vore            order  \
# 69          Arctic ground squirrel  Spermophilus  herbi         Rodentia
# 75       Eastern american chipmunk        Tamias  herbi         Rodentia
# 4                              Cow           Bos  herbi     Artiodactyla
# 78                      Tree shrew        Tupaia   omni       Scandentia
# 29                         Giraffe       Giraffa  herbi     Artiodactyla
# 62                      Rock hyrax      Procavia    NaN       Hyracoidea
# 24               European hedgehog     Erinaceus   omni   Erinaceomorpha
# 37                         Macaque        Macaca   omni         Primates
# 76                 Brazilian tapir       Tapirus  herbi   Perissodactyla
# 31                       Gray seal  Haliochoerus  carni        Carnivora
# 8                              Dog         Canis  carni        Carnivora
# 44                      Slow loris     Nyctibeus  carni         Primates
# ...

# %% [markdown]
# ເປັນການເບິ່ງລາຍລະອຽດຂອງຂໍ້ມູນ ແລະ ຍັງສາມາດເບິ່ງ missing value ຂອງແຕ່ລະ columns ໄດ້ອີກດ້ວຍ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 69 to 81
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          20 non-null     object
#  1   genus         20 non-null     object
#  2   vore          18 non-null     object
#  3   order         20 non-null     object
#  4   conservation  14 non-null     object
#  5   sleep_total   20 non-null     float64
#  6   sleep_rem     14 non-null     float64
#  7   sleep_cycle   9 non-null      float64
#  8   awake         20 non-null     float64
#  9   brainwt       16 non-null     float64
#  10  bodywt        20 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 1.9+ KB

# %% [markdown]
# ກວດສອບວ່າ column vore ມີ field ໃດທີ່ missing value

# %%
df[df.vore.isna()]
# Out:
#           name     genus vore         order conservation  sleep_total  \
# 62  Rock hyrax  Procavia  NaN    Hyracoidea           lc          5.4
# 72  Musk shrew    Suncus  NaN  Soricomorpha          NaN         12.8
#
#     sleep_rem  sleep_cycle  awake  brainwt  bodywt
# 62        0.5          NaN   18.6  0.02100   3.600
# 72        2.0     0.183333   11.2  0.00033   0.048

# %% [markdown]
# ເປັນການ import sklearn library ເຂົ້າມາໃຊ້
# ແລ້ວ import SimpleImputer library ເຂົ້າມາໃຊ້

# %%
import sklearn
from sklearn.impute import SimpleImputer

# %% [markdown]
# ເປັນການກວດສອບ version ຂອງ sklearn library

# %%
print(f'sklearn version: {sklearn.__version__}')
# Out:
# sklearn version: 1.0.2

# %% [markdown]
# ເປັນການແທນຄ່າວ່າງຂອງ column vore ດ້ວຍຄ່າທີ່ມີຄວາມຖີ່ຫຼາຍທີ່ສຸດໃນ column

# %%
imp = SimpleImputer(strategy="most_frequent")
imp.fit_transform(df[['vore']])
# Out:
# array([['herbi'],
#        ['herbi'],
#        ['herbi'],
#        ['omni'],
#        ['herbi'],
#        ['herbi'],
#        ['omni'],
#        ['omni'],
#        ['herbi'],
#        ['carni'],
#        ['carni'],
#        ['carni'],
#        ['herbi'],
#        ['herbi'],
#        ['carni'],
#        ['herbi'],
#        ['herbi'],
#        ['omni'],
#        ['herbi'],
#        ['carni']], dtype=object)

# %% [markdown]
# ສ້າງ column vore2 ເພື່ອມາປຽບທຽບກັບ column vore ວ່າ column vore ນັ້ນ ຖືກແທນດ້ວຍຄ່າໃດ

# %%
df['vore2']=imp.fit_transform(df[['vore']])
df[df.vore.isna()][['name', 'vore', 'vore2']]
# Out:
#           name vore  vore2
# 62  Rock hyrax  NaN  herbi
# 72  Musk shrew  NaN  herbi

# %% [markdown]
# ສ້າງ column vore2 ຂື້ນມາ ແລ້ວຕື່ມຄ່າທີ່ກຳນົດຂຶ້ນມາເອງ (omni)

# %%
imp2 = SimpleImputer(strategy="constant", fill_value='omni')
df['vore3']=imp2.fit_transform(df[['vore']])
df[df.vore.isna()][['name', 'vore', 'vore2', 'vore3']]
# Out:
#           name vore  vore2 vore3
# 62  Rock hyrax  NaN  herbi  omni
# 72  Musk shrew  NaN  herbi  omni

# %% [markdown]
# ຈາກ column sleep_rem ດຶງ field ທີ່ມີຄ່າວ່າງຂຶ້ນມາ
# ແລ້ວສ້າງ column sleep_rem4 ຂື້ນມາ ເພື່ອແທນທີ່ດ້ວຍຄ່າ -99

# %%
# imp3=SimpleImputer(strategy='mean')
# imp3=SimpleImputer(strategy='median')
imp3=SimpleImputer(strategy='constant', fill_value=-99)
df['sleep_rem4']=imp3.fit_transform(df[['sleep_rem']])
df[df.sleep_rem.isna()][['name', 'sleep_rem', 'sleep_rem4']]
# Out:
#                          name  sleep_rem  sleep_rem4
# 69     Arctic ground squirrel        NaN       -99.0
# 75  Eastern american chipmunk        NaN       -99.0
# 44                 Slow loris        NaN       -99.0
# 9                    Roe deer        NaN       -99.0
# 59            Common porpoise        NaN       -99.0
# 81                 Arctic fox        NaN       -99.0

# %% [markdown]
# ຈາກ column sleep_rem4 ດຶງ field ທີ່ມີຄ່າ -99 ຂຶ້ນມາ
# ແລ້ວສ້າງ column sleep_rem5 ຂື້ນມາ ເພື່ອແທນທີ່ດ້ວຍຄ່າ NaN

# %%
# imp_x=SimpleImputer(strategy='mean')
# imp_x=SimpleImputer(strategy='median')
# imp_x=SimpleImputer(strategy='most_frequent')
imp_x=SimpleImputer(missing_values=-99, strategy='constant', fill_value=np.nan)

df['sleep_rem5']=imp_x.fit_transform(df[['sleep_rem4']])
df[df.sleep_rem4==-99.0][['name', 'sleep_rem4', 'sleep_rem5']]
# Out:
#                          name  sleep_rem4  sleep_rem5
# 69     Arctic ground squirrel       -99.0         NaN
# 75  Eastern american chipmunk       -99.0         NaN
# 44                 Slow loris       -99.0         NaN
# 9                    Roe deer       -99.0         NaN
# 59            Common porpoise       -99.0         NaN
# 81                 Arctic fox       -99.0         NaN

# %% [markdown]
# ເປັນການປ່ຽນຄ່າ NaN ໃຫ້ເປັນຄ່າ mean (2.0)

# %%
imp_x=SimpleImputer(strategy='mean')
# imp_x=SimpleImputer(strategy='median')
# imp_x=SimpleImputer(strategy='most_frequent')
# imp_x=SimpleImputer(missing_values=-99, strategy='constant', fill_value=np.nan)

df['sleep_rem6']=imp_x.fit_transform(df[['sleep_rem5']])
df[df.sleep_rem5.isna()][['name', 'sleep_rem4', 'sleep_rem5', 'sleep_rem6']]
# Out:
#                          name  sleep_rem4  sleep_rem5  sleep_rem6
# 69     Arctic ground squirrel       -99.0         NaN         2.0
# 75  Eastern american chipmunk       -99.0         NaN         2.0
# 44                 Slow loris       -99.0         NaN         2.0
# 9                    Roe deer       -99.0         NaN         2.0
# 59            Common porpoise       -99.0         NaN         2.0
# 81                 Arctic fox       -99.0         NaN         2.0
